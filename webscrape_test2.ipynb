# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup
import time
import random
from webscraper import *

# %%
def get_song_urls_list(url):
    song_urls_list = []

    r = requests.get(url)
    soup = BeautifulSoup(r.text, 'html.parser')

    for a in soup.find_all('a', {'rel': 'bookmark'}):
        song_urls_list.append(a['href'])
    return song_urls_list


def scrape_first_page(start_url, empty_df):
    
    start_urls_list = get_song_urls_list(start_url)
    z = 1
    for url in start_urls_list:
        print(f'starting song: {z}')
        print(url)
        z+=1
        
        r = requests.get(url)
        soup = BeautifulSoup(r.text, 'html.parser')
        tags = soup.find_all(['td','p'])
        td_tags = soup.find_all(['td'])
        p_tags = soup.find_all(['p'])
        
        kor = pd.DataFrame()
        eng = pd.DataFrame()

        if (td_tags[-1].text=='N/A') | (td_tags[-1].text=='soon') | (td_tags[-1].text=='Coming Soon!') | (len(tags)<25) | (p_tags[-3].text[0:6]!='Korean'):
            time.sleep(random.randint(5,8))
            continue
        else:
            c = len(tags) - 3
            d = c - 7
            e = int(d/3)
            a = e + 7
            b = e + a

            for i in range(a,b):
                kor_lines = tags[i]
                kor_lines_series = pd.Series(kor_lines.text.split('\n'))
                kor = pd.concat([kor, kor_lines_series])
                kor = kor[kor[0]!=""]
            kor = kor.rename(columns={0:'kor'})

            for i in range(b,c):
                eng_lines = tags[i]
                eng_lines_series = pd.Series(eng_lines.text.split('\n'))
                eng = pd.concat([eng, eng_lines_series])
                eng = eng[eng[0]!=""]
            eng = eng.rename(columns={0:'eng'})
            
            if eng.shape != kor.shape:
                time.sleep(random.randint(5,8))
                continue
            else:
                concatted = pd.concat([eng, kor],axis=1)
                concatted = concatted.drop_duplicates()
                concatted = concatted.query("eng != kor")

                empty_df = pd.concat([empty_df,concatted])

                time.sleep(random.randint(6,9))
    return empty_df


def scrape_it(start_url, empty_df, end):
    
    z=1
    print(f'Starting page: {z}')
    df = scrape_first_page(start_url, empty_df)
    
    for i in range(99,end+1):
        
        z+=1
        print(f'Starting page: {z}')
        next_url = f'https://colorcodedlyrics.com/category/krn/page/{i}'

        urls_list = get_song_urls_list(next_url)
        if (i==100) | (i==200) | (i==300) | (i==400) | (i==500) | (i==600) | (i==700):
            df.to_csv('lyrics_save{}.csv'.format(i), sep='\t')
            df.to_csv('lyrics_save{}.txt'.format(i), sep='\t')
            print(f'saved up tp page: {i}')

        for url in urls_list:

            r = requests.get(url)
            soup = BeautifulSoup(r.text, 'html.parser')
            tags = soup.find_all(['td','p'])
            td_tags = soup.find_all(['td'])
            p_tags = soup.find_all(['p'])
            
            kor = pd.DataFrame()
            eng = pd.DataFrame()

            if (td_tags[-1].text=='N/A') | (td_tags[-1].text=='soon') | (td_tags[-1].text=='Coming Soon!') | (len(tags)<25) | (p_tags[-3].text[0:6]!='Korean'):
                time.sleep(random.randint(5,8))
                continue
            else:
                c = len(tags) - 3
                d = c - 7
                e = int(d/3)
                a = e + 7
                b = e + a

                for i in range(a,b):
                    kor_lines = tags[i]
                    kor_lines_series = pd.Series(kor_lines.text.split('\n'))
                    kor = pd.concat([kor, kor_lines_series])
                    kor = kor[kor[0]!=""]
                kor = kor.rename(columns={0:'kor'})

                for i in range(b,c):
                    eng_lines = tags[i]
                    eng_lines_series = pd.Series(eng_lines.text.split('\n'))
                    eng = pd.concat([eng, eng_lines_series])
                    eng = eng[eng[0]!=""]
                eng = eng.rename(columns={0:'eng'})

                if eng.shape != kor.shape:
                    time.sleep(random.randint(5,8))
                    continue
                else:
                    concatted = pd.concat([eng, kor],axis=1)
                    concatted = concatted.drop_duplicates()
                    concatted = concatted.query("eng != kor")

                    df = pd.concat([df,concatted])

                    time.sleep(random.randint(5,8))

        
    return df

# %%
url = 'https://colorcodedlyrics.com/category/krn/page/101'
empty = pd.DataFrame(columns = ['eng','kor'])
df = scrape_first_page(start_url=url, empty_df=empty)
# Out:
# starting song: 1
# https://colorcodedlyrics.com/2019/03/stray-kids-chronosaurus
# starting song: 2
# https://colorcodedlyrics.com/2019/03/stray-kids-boxer
# starting song: 3
# https://colorcodedlyrics.com/2019/03/stray-kids-maze-of-memories-jamgganui-goyo
# starting song: 4
# https://colorcodedlyrics.com/2019/03/stray-kids-victory-song-seungjeonga
# starting song: 5
# https://colorcodedlyrics.com/2019/03/momoland-what-you-want
# starting song: 6
# https://colorcodedlyrics.com/2019/03/momoland-holiday
# starting song: 7
# https://colorcodedlyrics.com/2019/03/momoland-light-up-bichna
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-15-b4921547951b> in <module>
#       1 url = 'https://colorcodedlyrics.com/category/krn/page/101'
#       2 empty = pd.DataFrame(columns = ['eng','kor'])
# ----> 3 df = scrape_first_page(start_url=url, empty_df=empty)
#
# <ipython-input-14-51c2ec4bc5b6> in scrape_first_page(start_url, empty_df)
#      56                 continue
#      57             else:
# ---> 58                 concatted = pd.concat([eng, kor],axis=1)
#      59                 concatted = concatted.drop_duplicates()
#      60                 concatted = concatted.query("eng != kor")
#
# ~\Anaconda3\lib\site-packages\pandas\core\reshape\concat.py in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     282     )
#     283
# --> 284     return op.get_result()
#     285
#     286
#
# ~\Anaconda3\lib\site-packages\pandas\core\reshape\concat.py in get_result(self)
#     495
#     496             new_data = concatenate_block_managers(
# --> 497                 mgrs_indexers, self.new_axes, concat_axis=self.axis, copy=self.copy
#     498             )
#     499             if not self.copy:
#
# ~\Anaconda3\lib\site-packages\pandas\core\internals\managers.py in concatenate_block_managers(mgrs_indexers, axes, concat_axis, copy)
#    2025         blocks.append(b)
#    2026
# -> 2027     return BlockManager(blocks, axes)
#
# ~\Anaconda3\lib\site-packages\pandas\core\internals\managers.py in __init__(self, blocks, axes, do_integrity_check)
#     137
#     138         if do_integrity_check:
# --> 139             self._verify_integrity()
#     140
#     141         self._consolidate_check()
#
# ~\Anaconda3\lib\site-packages\pandas\core\internals\managers.py in _verify_integrity(self)
#     332         for block in self.blocks:
#     333             if block._verify_integrity and block.shape[1:] != mgr_shape[1:]:
# --> 334                 construction_error(tot_items, block.shape[1:], self.axes)
#     335         if len(self.items) != tot_items:
#     336             raise AssertionError(
#
# ~\Anaconda3\lib\site-packages\pandas\core\internals\managers.py in construction_error(tot_items, block_shape, axes, e)
#    1692     if block_shape[0] == 0:
#    1693         raise ValueError("Empty data passed with indices specified.")
# -> 1694     raise ValueError(f"Shape of passed values is {passed}, indices imply {implied}")
#    1695
#    1696
#
# ValueError: Shape of passed values is (755, 2), indices imply (73, 2)

# %%
url = 'https://colorcodedlyrics.com/2019/03/momoland-light-up-bichna'

r = requests.get(url)
soup = BeautifulSoup(r.text, 'html.parser')
tags = soup.find_all(['td','p'])
td_tags = soup.find_all(['td'])
p_tags = soup.find_all(['p'])

# %%
kor = pd.DataFrame()
eng = pd.DataFrame()

c = len(tags) - 3
d = c - 7
e = int(d/3)
a = e + 7
b = e + a

for i in range(a,b):
    kor_lines = tags[i]
    kor_lines_series = pd.Series(kor_lines.text.split('\n'))
    kor = pd.concat([kor, kor_lines_series])
    kor = kor[kor[0]!=""]
kor = kor.rename(columns={0:'kor'})

for i in range(b,c):
    eng_lines = tags[i]
    eng_lines_series = pd.Series(eng_lines.text.split('\n'))
    eng = pd.concat([eng, eng_lines_series])
    eng = eng[eng[0]!=""]
eng = eng.rename(columns={0:'eng'})

# %%
kor
# Out:
#                                  kor
# 0       Who else could do it better?
# 1             Uha uha nobody but me!
# 0   빛나! 저 태양처럼(just do it like this)
# 1   Only one 내가 되고 싶어(nobody but me)
# 2   빛나! 저 태양처럼(just do it like this)
# ..                               ...
# 0   빛나! 저 태양처럼(just do it like this)
# 1   Only one 내가 되고 싶어(nobody but me)
# 2   빛나! 저 태양처럼(just do it like this)
# 3                  날 믿어 get a chance
# 4                     우리 아님 누가 lucky
#
# [73 rows x 1 columns]

# %%
eng
# Out:
#                                             eng
# 0                  Who else could do it better?
# 1                        Uha uha nobody but me!
# 0   I shine like the sun (Just do it like this)
# 1     Only one, I want to be me (Nobody but me)
# 2   I shine like the sun (Just do it like this)
# ..                                          ...
# 0   I shine like the sun (Just do it like this)
# 1     Only one, I want to be me (Nobody but me)
# 2   I shine like the sun (Just do it like this)
# 3                   Believe in me, get a chance
# 4                     Who would shine if not us
#
# [73 rows x 1 columns]

# %%
url = 'https://colorcodedlyrics.com/2019/03/momoland-light-up-bichna'
r = requests.get(url)
soup = BeautifulSoup(r.text, 'html.parser')
tags = soup.find_all(['td','p'])
td_tags = soup.find_all(['td'])
p_tags = soup.find_all(['p'])

kor = pd.DataFrame()
eng = pd.DataFrame()
df = pd.DataFrame(columns = ['eng','kor'])

c = len(tags) - 3
d = c - 7
e = int(d/3)
a = e + 7
b = e + a

for i in range(a,b):
    kor_lines = tags[i]
    kor_lines_series = pd.Series(kor_lines.text.split('\n'))
    kor = pd.concat([kor, kor_lines_series])
    kor = kor[kor[0]!=""]
kor = kor.rename(columns={0:'kor'}).reset_index().drop(columns='index')

for i in range(b,c):
    eng_lines = tags[i]
    eng_lines_series = pd.Series(eng_lines.text.split('\n'))
    eng = pd.concat([eng, eng_lines_series])
    eng = eng[eng[0]!=""]
eng = eng.rename(columns={0:'eng'}).reset_index().drop(columns='index')

# if eng.shape != kor.shape:
#     time.sleep(random.randint(5,8))
#     continue
# else:
concatted = pd.concat([eng, kor],axis=1)
concatted = concatted.drop_duplicates()
concatted = concatted.query("eng != kor")

df = pd.concat([df,concatted])

# time.sleep(random.randint(5,8))

# %%
df
# Out:
#                                                   eng  \
# 2         I shine like the sun (Just do it like this)
# 3           Only one, I want to be me (Nobody but me)
# 5                         Believe in me, get a chance
# 6                           Who would shine if not us
# 7         Good luck follows me, everyone is gathering
# 8                    Even further, gathering wordwide
# 9   You have too much confidence, who do you think...
# 10                 Everyone asks me, but I just do it
# 11                                 Nobody, not anyone
# 12                                     Can replace me
# 13           Someone like that doesn’t exist, because
# 14                         I choose my own path, baby
# 15                             I don’t want to follow
# 16                               Other people too far
# 17          I want to live trying everything I can do
# 18                                   Just be who I am
# 19                        Who would make it if not me
# 20                                Tomorrow is unknown
# 21                  No wait, I’m choosing my path now
# 22                                I’ll make every day
# 23              The super duper lucky that came to me
# 24                                              Lucky
# 25                               Get ready, I’m ready
# 26                        I’ll show you my everything
# 33                           Sing a song, na na na na
# 34                                   Someone be happy
# 35                               Like that bright sun
# 36                             I’ll become your light
# 37          It seems like you’ll fail but you succeed
# 38          It seems like you’ll succeed but you fail
# 39        Don’t mind it too much, what does it matter
# 40                               I’ll be by your side
# 41                           I’ll sing a song for you
# 42                     You can trust me and follow me
# 43                              The future is unknown
# 44                   No way, I’m choosing my path now
# 45                        I’ll make everything I have
# 48                               Get ready, I’m ready
# 61                        Sing along to my song, baby
# 62                                        Super lucky
# 63                            This moment is the best
# 65          There is no place where it can’t be heard
# 66                           Believe me, get a chance
# 67                             Who is lucky if not us
# 72                          Who would shine if not us
#
#                                  kor
# 2   빛나! 저 태양처럼(just do it like this)
# 3   Only one 내가 되고 싶어(nobody but me)
# 5                  날 믿어 get a chance
# 6                        우리 아님 누가 빛나
# 7          행운 follow me 모두 gathering
# 8       더 멀리 world wide 까지 gathering
# 9                  뭘 믿고 자신감 too much
# 10                  묻는데 나 just do it
# 11                      nobody 그 누구도
# 12                         대체 할 수 없어
# 13                         어디 없어 왜냐면
# 14                   내 길 내가 결정해 baby
# 15                          가고 싶진 않아
# 16                         남 따라 저 멀리
# 17             할 수 있는 모든 건 다 해보면서 살래
# 18                          just 나답게
# 19                   나 아님 누가 make it
# 20                        내일을 알 순 없어
# 21               No wait 내 길 now 선택해
# 22                    매일을 전부 make it
# 23            내게 온 super duper lucky
# 24                          (lucky~)
# 25                  Get ready 준비 됐어.
# 26                        보여 줄 내 전부를
# 33                  Sing a song 나나나나
# 34                      누군가 be happy
# 35                        눈부신 저 태양처럼
# 36                          네게 빛이 될게
# 37                           안되다가도 돼
# 38                         되다가도 fail
# 39                     신경쓰지 마 좀 뭐 어때
# 40                            곁에 있을게
# 41                       너 위한 노랠 부를게
# 42                      날 믿고 따라 와도 돼
# 43                        미래를 알 순 없어
# 44                No way 내 길 now 선택해
# 45                  내 모두를 전부 make it
# 48                   Get ready 준비 됐어
# 61                  내 노래 따라 불러줘 baby
# 62                       super lucky
# 63                          최고의 이순간을
# 65                       안 들리는 데가 없어
# 66                   믿어 get a chance
# 67                    우리 아님 누가 lucky
# 72                    우리 아님 누가 lucky

# %%
eng.shape
# Out:
# (73, 1)

# %%
kor.shape
# Out:
# (73, 1)

# %%
eng
# Out:
#                                             eng
# 0                  Who else could do it better?
# 1                        Uha uha nobody but me!
# 0   I shine like the sun (Just do it like this)
# 1     Only one, I want to be me (Nobody but me)
# 2   I shine like the sun (Just do it like this)
# ..                                          ...
# 0   I shine like the sun (Just do it like this)
# 1     Only one, I want to be me (Nobody but me)
# 2   I shine like the sun (Just do it like this)
# 3                   Believe in me, get a chance
# 4                     Who would shine if not us
#
# [73 rows x 1 columns]

# %%
kor
# Out:
#                                  kor
# 0       Who else could do it better?
# 1             Uha uha nobody but me!
# 0   빛나! 저 태양처럼(just do it like this)
# 1   Only one 내가 되고 싶어(nobody but me)
# 2   빛나! 저 태양처럼(just do it like this)
# ..                               ...
# 0   빛나! 저 태양처럼(just do it like this)
# 1   Only one 내가 되고 싶어(nobody but me)
# 2   빛나! 저 태양처럼(just do it like this)
# 3                  날 믿어 get a chance
# 4                     우리 아님 누가 lucky
#
# [73 rows x 1 columns]

# %%
start_url = 'https://colorcodedlyrics.com/category/krn'

empty = pd.DataFrame(columns = ['eng','kor'])

df = scrape_it(start_url=start_url, empty_df=empty, end=3)
# Out:
# Starting page: 1
# Starting page: 2
# Starting page: 3

# %%
url = ['https://colorcodedlyrics.com/2019/08/content-survey','https://colorcodedlyrics.com/2019/08/up10tion-your-gravity']
for i in url:
    r = requests.get(url)
    soup = BeautifulSoup(r.text, 'html.parser')
    tags = soup.find_all(['td','p'])
    td_tags = soup.find_all(['td'])
    p_tags = soup.find_all(['p'])
    
    if

# %%
len(td_tags)
# Out:
# 0

# %%
p_tags[-3].text[0:6]
# Out:
# 'Which '

# %%
kor = pd.DataFrame()
eng = pd.DataFrame()
df = pd.DataFrame(columns = ['eng','kor'])

c = len(tags) - 3
d = c - 7
e = int(d/3)
a = e + 7
b = e + a

for i in range(a,b):
    kor_lines = tags[i]
    kor_lines_series = pd.Series(kor_lines.text.split('\n'))
    kor = pd.concat([kor, kor_lines_series])
    kor = kor[kor[0]!=""]
kor = kor.rename(columns={0:'kor'}).reset_index().drop(columns='index')

for i in range(b,c):
    eng_lines = tags[i]
    eng_lines_series = pd.Series(eng_lines.text.split('\n'))
    eng = pd.concat([eng, eng_lines_series])
    eng = eng[eng[0]!=""]
eng = eng.rename(columns={0:'eng'}).reset_index().drop(columns='index')

# if eng.shape != kor.shape:
#     time.sleep(random.randint(5,8))
#     continue
# else:
concatted = pd.concat([eng, kor],axis=1)
concatted = concatted.drop_duplicates()
concatted = concatted.query("eng != kor")

df = pd.concat([df,concatted])

# time.sleep(random.randint(5,8))
